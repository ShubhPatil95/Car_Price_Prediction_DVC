# %%
import argparse
import mlflow
from mlflow.tracking import MlflowClient
from pprint import pprint
import joblib
import os
import yaml


def read_file(file_path):
    with open(file_path) as yaml_file:
        file=yaml.safe_load(yaml_file)
    return file

def log_production_model(config_path):
    config = read_file(config_path)
    
    
    mlflow_config = config["mlflow_config"] 
    

    model_name = mlflow_config["registered_model_name"]


    remote_server_uri = mlflow_config["remote_server_uri"]
    
    mlflow.set_tracking_uri(remote_server_uri)
    
    runs = mlflow.search_runs(experiment_ids=1)
    
    print(runs)
    
    ####### mention you metrics name checking its name in mlflow dashboard#########
    
    lowest = runs["metrics.training_mae"].sort_values(ascending=True)[0]
    
    lowest_run_id = runs[runs["metrics.training_mae"] == lowest]["run_id"][0]
    client = MlflowClient()
    
    
    for mv in client.search_model_versions(f"name='{model_name}'"):
        mv = dict(mv)
        
        if mv["run_id"] == lowest_run_id:
            current_version = mv["version"]
            logged_model = mv["source"]
            pprint(mv, indent=4)
            client.transition_model_version_stage(
                name=model_name,
                version=current_version,
                stage="Production"
            )
        else:
            current_version = mv["version"]
            client.transition_model_version_stage(
                name=model_name,
                version=current_version,
                stage="Staging"
            )        

log_production_model("/home/shubham/car_dekho_project/Car_Dekho/params.yaml")
# Out:
#                              run_id experiment_id    status  \
# 0  2197ef5fa14b450f97c1cca3dc93a13c             1  FINISHED
# 1  4ed1bb8cf5514bbeb14305de4d1f132c             1  FINISHED
# 2  569ebf12aeba4500a332e4dea0496b62             1  FINISHED
# 3  64b790393f7f464a8442cf9bf0e6e83c             1  FINISHED
# 4  6f4ad766a1304f5493994e06ffa8fc21             1  FINISHED
# 5  d46c378ac8b44d05813691cb599a870c             1  FINISHED
#
#                                         artifact_uri  \
# 0  ./artifacts/1/2197ef5fa14b450f97c1cca3dc93a13c...
# 1  ./artifacts/1/4ed1bb8cf5514bbeb14305de4d1f132c...
# 2  ./artifacts/1/569ebf12aeba4500a332e4dea0496b62...
# 3  ./artifacts/1/64b790393f7f464a8442cf9bf0e6e83c...
# 4  ./artifacts/1/6f4ad766a1304f5493994e06ffa8fc21...
# 5  ./artifacts/1/d46c378ac8b44d05813691cb599a870c...
#
#                         start_time                         end_time  \
# 0 2022-02-22 10:38:54.272000+00:00 2022-02-22 10:40:21.538000+00:00
# 1 2022-02-22 10:38:54.272000+00:00 2022-02-22 10:39:58.163000+00:00
# 2 2022-02-22 10:38:54.272000+00:00 2022-02-22 10:39:58.163000+00:00
# 3 2022-02-22 10:38:54.272000+00:00 2022-02-22 10:39:58.163000+00:00
# 4 2022-02-22 10:38:54.272000+00:00 2022-02-22 10:39:58.163000+00:00
# 5 2022-02-22 10:38:54.272000+00:00 2022-02-22 10:39:58.163000+00:00
#
#    metrics.training_mae  metrics.training_rmse  \
# 0              0.443639               0.844881
# 1                   NaN                    NaN
# 2                   NaN                    NaN
# 3                   NaN                    NaN
# 4                   NaN                    NaN
# 5                   NaN                    NaN
#
#    metrics.mean_absolute_error_X_test  metrics.best_cv_score  ...  \
# 0                            0.961125              -2.948735  ...
# 1                                 NaN                    NaN  ...
# 2                                 NaN                    NaN  ...
# 3                                 NaN                    NaN  ...
# 4                                 NaN                    NaN  ...
# 5                                 NaN                    NaN  ...
#
#    tags.mlflow.runName                               tags.estimator_class  \
# 0                mlops  sklearn.model_selection._search.RandomizedSear...
# 1                 None     sklearn.ensemble._forest.RandomForestRegressor
# 2                 None     sklearn.ensemble._forest.RandomForestRegressor
# 3                 None     sklearn.ensemble._forest.RandomForestRegressor
# 4                 None     sklearn.ensemble._forest.RandomForestRegressor
# 5                 None     sklearn.ensemble._forest.RandomForestRegressor
#
#                              tags.mlflow.source.name    tags.estimator_name  \
# 0  /home/shubham/car_dekho_project/Car_Dekho/src/...     RandomizedSearchCV
# 1  /home/shubham/car_dekho_project/Car_Dekho/src/...  RandomForestRegressor
# 2  /home/shubham/car_dekho_project/Car_Dekho/src/...  RandomForestRegressor
# 3  /home/shubham/car_dekho_project/Car_Dekho/src/...  RandomForestRegressor
# 4  /home/shubham/car_dekho_project/Car_Dekho/src/...  RandomForestRegressor
# 5  /home/shubham/car_dekho_project/Car_Dekho/src/...  RandomForestRegressor
#
#               tags.mlflow.source.git.commit  tags.mlflow.source.type  \
# 0  b2fbdea13ef9c62b412b3ac6e0b4828a8878525d                    LOCAL
# 1  b2fbdea13ef9c62b412b3ac6e0b4828a8878525d                    LOCAL
# 2  b2fbdea13ef9c62b412b3ac6e0b4828a8878525d                    LOCAL
# 3  b2fbdea13ef9c62b412b3ac6e0b4828a8878525d                    LOCAL
# 4  b2fbdea13ef9c62b412b3ac6e0b4828a8878525d                    LOCAL
# 5  b2fbdea13ef9c62b412b3ac6e0b4828a8878525d                    LOCAL
#
#    tags.mlflow.user                      tags.mlflow.log-model.history  \
# 0           shubham  [{"run_id": "2197ef5fa14b450f97c1cca3dc93a13c"...
# 1           shubham                                               None
# 2           shubham                                               None
# 3           shubham                                               None
# 4           shubham                                               None
# 5           shubham                                               None
#
#    tags.mlflow.autologging           tags.mlflow.parentRunId
# 0                     None                              None
# 1                  sklearn  2197ef5fa14b450f97c1cca3dc93a13c
# 2                  sklearn  2197ef5fa14b450f97c1cca3dc93a13c
# 3                  sklearn  2197ef5fa14b450f97c1cca3dc93a13c
# 4                  sklearn  2197ef5fa14b450f97c1cca3dc93a13c
# 5                  sklearn  2197ef5fa14b450f97c1cca3dc93a13c
#
# [6 rows x 63 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_607059/729259112.py in <module>
#      59             )
#      60
# ---> 61 log_production_model("/home/shubham/car_dekho_project/Car_Dekho/params.yaml")
#
# /tmp/ipykernel_607059/729259112.py in log_production_model(config_path)
#      35     lowest = runs["metrics.mean_test_score"].sort_values(ascending=True)[0]
#      36
# ---> 37     lowest_run_id = runs[runs["metrics.mean_test_score"] == lowest]["run_id"][0]
#      38     client = MlflowClient()
#      39
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 0
